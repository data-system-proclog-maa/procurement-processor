# %%
import pandas as pd
import numpy as np
import os

import sys
sys.path.append(os.path.abspath(os.path.join('../pipeline')))

import data_loader
import data_helper
import processing_steps

# %%
loaded_data = data_loader.load_all_data()

# %%
df = loaded_data['df']
holidays_df = loaded_data['holidays_df']
wilayah_df = loaded_data['wilayah_df']
pulau_df = loaded_data['pulau_df']
jasa_service_df = loaded_data['jasa_service_df']
freight_df = loaded_data['freight_df']
rara_df = loaded_data['rara_df']
ryi_df = loaded_data['ryi_df']
cost_saving_df = loaded_data['cost_saving_df']
picnorm_df = loaded_data['picnorm_df']
ontime_normalized_df = loaded_data['ontime_normalized_df']
timedate_normalized_df = loaded_data['timedate_normalized_df']
notcounted_df = loaded_data['notcounted_df']
logistic_normalized_df = loaded_data['logistic_normalized_df']

df = processing_steps.run_all_processing(
    df, picnorm_df, holidays_df, wilayah_df, pulau_df, jasa_service_df, 
    freight_df, rara_df, ryi_df, 
    cost_saving_df, timedate_normalized_df, 
    ontime_normalized_df, notcounted_df, logistic_normalized_df
)
# Out:
# preparing data and normalizing dates...
# running step 1: initial feature engineering...
# running step 2: time-based calculations...
# calculating purchasing on-time metric...
# running step 3: logistics & receiving status...
# running step 4: fully received po status...
# running step 5: jasa service merge...
# running step 6a: apply purchasing business rule normalizations...
# running step 6b: applying manual delivery on-time normalizations...
# running step 6c: applying logistic on-time normalizations...
# running step 7: apply cost saving updates...
# creating final_itemid (using item id as final id)...
# applying routine categorization updates...
# pulling unnormalized on time%...
# updating 2024 logistic cost saving...
# reordering columns and performing final cleanup...
# processing complete!

# %%
df
# Out:
#       Requisition Type  Item ID  \
# 0              General    73471
# 1              General    60402
# 2              General    62065
# 3              General    52621
# 4              General    73814
# ...                ...      ...
# 79265          General    11013
# 79266          General    21878
# 79267          General    21880
# 79268          General    23253
# 79269          General     4639
#
#                                                Item Name  \
# 0                                      Face Shield UV400
# 1                        4C4782 Oring Kit Oring Box - HG
# 2      DCD805 D2 Cordless Brushless Hammer Drill 20 V...
# 3      Digital Delay Timer Trigger On-Off Mosfet 5-36...
# 4      Banner Internal Ukuran Panjang 3 Meter x Lebar...
# ...                                                  ...
# 79265                          Obat Fogging CYNOFF 50 EC
# 79266                                             Bensin
# 79267                         Oli Samping Evalube 800 ml
# 79268                               Isolasi 3M Scotch 33
# 79269                    Auto Lamp Bulb H3-24V-70W Bosch
#
#                    Item Category                         Department    Unit  \
# 0                            APD       MMP-PLNT__Seragam_Safety-LAR     Pcs
# 1            Tools dan Alat Ukur  BTG-PLNT__Tools_Besi_Cat_Pipa-OBI     box
# 2            Tools dan Alat Ukur  BTG-PLNT__Tools_Besi_Cat_Pipa-OBI     pcs
# 3      Spare Part EXC 370CA XCMG             BTG-PLNT__A2B_Accu-OBI     Pcs
# 4                          Cetak       MMP-OPS_HSE_Enviro_Cetak-OBI  Lembar
# ...                          ...                                ...     ...
# 79265         x Kebutuhan Enviro              x BCPM-OPS_HSE-LC-LAR   Botol
# 79266  x Workshop dan Elektrikal                 x BCPM-HRGA-LC-LAR   Liter
# 79267     x Kebutuhan Konstruksi                 x BCPM-HRGA-LC-LAR     Pcs
# 79268  x Workshop dan Elektrikal                  x BTG-HRGA-LC-OBI     pcs
# 79269  x Workshop dan Elektrikal                  x BTG-PLNT-LC-OBI     Pcs
#
#       Currency  Exchange Rate   PO Price  Qty Order  ...  \
# 0          IDR            1.0    40000.0       10.0  ...
# 1          IDR            1.0  1700000.0        3.0  ...
# 2          IDR            1.0  3500000.0        2.0  ...
# 3          IDR            1.0    37500.0       20.0  ...
# 4          IDR            1.0    69000.0        1.0  ...
# ...        ...            ...        ...        ...  ...
# 79265      IDR            1.0   202702.7        5.0  ...
# 79266      IDR            1.0    13500.0       20.0  ...
# 79267      IDR            1.0    40000.0        2.0  ...
# 79268      IDR            1.0    43650.0       10.0  ...
# 79269      IDR            1.0    30000.0       50.0  ...
#
#        ON_TIME%_overall_original  ON_TIME%_original_purchasing  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 79265                        1.0                           1.0
# 79266                        1.0                           1.0
# 79267                        1.0                           1.0
# 79268                        1.0                           1.0
# 79269                        1.0                           1.0
#
#        ON_TIME%_logistic  Final_ItemID Purchasing_Duration STATUS_Purchasing  \
# 0                    NaN         73471                 NaN              None
# 1                    NaN         60402                 NaN              None
# 2                    NaN         62065                 NaN              None
# 3                    NaN         52621                 NaN              None
# 4                    NaN         73814                 NaN              None
# ...                  ...           ...                 ...               ...
# 79265                NaN         11013                 NaN              None
# 79266                NaN         21878                 NaN              None
# 79267                NaN         21880                 NaN              None
# 79268                NaN         23253                 NaN              None
# 79269                NaN          4639                 NaN              None
#
#       ON_TIME_Purchasing LATE_Purchasing ON_TIME%_Purchasing     _Routine
# 0                    NaN             NaN                 NaN  Non-Routine
# 1                    NaN             NaN                 NaN      Routine
# 2                    NaN             NaN                 NaN      Routine
# 3                    NaN             NaN                 NaN      Routine
# 4                    NaN             NaN                 NaN  Non-Routine
# ...                  ...             ...                 ...          ...
# 79265                NaN             NaN                 NaN      Routine
# 79266                NaN             NaN                 NaN  Non-Routine
# 79267                NaN             NaN                 NaN  Non-Routine
# 79268                NaN             NaN                 NaN      Routine
# 79269                NaN             NaN                 NaN      Routine
#
# [79270 rows x 123 columns]

# %%
# Show available keys inside loaded_data and brief info for each dataframe/value
for k, v in loaded_data.items():
	print(f"Key: {k}")
	print(f"  Type: {type(v)}")
	if hasattr(v, "shape"):
		try:
			print(f"  Shape: {v.shape}")
			if hasattr(v, "columns"):
				print(f"  Columns: {list(v.columns[:8])}{'...' if len(v.columns) > 8 else ''}")
		except Exception as e:
			print(f"  (error inspecting dataframe) {e}")
	else:
		# print a short preview for non-dataframe values
		preview = repr(v)
		print(f"  Value preview: {preview[:200]}{'...' if len(preview) > 200 else ''}")
	print()
# Out:
# Key: df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (79263, 123)
#   Columns: ['Requisition Type', 'Item ID', 'Item Name', 'Item Category', 'Department', 'Unit', 'Currency', 'Exchange Rate']...
#
# Key: holidays_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (44, 1)
#   Columns: ['NONWORKDAYS']
#
# Key: wilayah_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (128, 2)
#   Columns: ['Supplier Location', 'To']
#
# Key: pulau_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (17, 2)
#   Columns: ['Wilayah', 'Pulau']
#
# Key: jasa_service_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (447, 4)
#   Columns: ['Item ID', 'PO Number', 'JS_SERVICE', 'uid']
#
# Key: cost_saving_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (2323, 8)
#   Columns: ['Requisition Type', 'Item Name', 'Item Category', 'Department', 'PO Number', 'Combined', 'Cost Saving', 'Unicode_Key']
#
# Key: freight_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (38, 3)
#   Columns: ['Supplier', 'Freight Type', 'Unnamed: 2']
#
# Key: rara_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (315, 2)
#   Columns: ['PO Number', 'Freight Type']
#
# Key: ryi_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (16, 2)
#   Columns: ['PO Number', 'Freight Type']
#
# Key: picnorm_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (101, 8)
#   Columns: ['Requisition Number', 'Updated Requisition Approved Date', 'Updated Requisition Required Date', 'Background Update', 'Tanggal Request', 'PIC Purchasing', 'Description', 'Category']
#
# Key: ontime_normalized_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (282, 6)
#   Columns: ['PO Number', 'Unnamed: 1', 'Unnamed: 2', 'Remarks', 'Detail_', 'Detail_2']
#
# Key: timedate_normalized_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (4, 2)
#   Columns: ['PO Number', 'timedate']
#
# Key: notcounted_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (10, 2)
#   Columns: ['PO Number', 'Remarks']
#
# Key: logistic_normalized_df
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Shape: (1603, 2)
#   Columns: ['PO Number', 'Value']
